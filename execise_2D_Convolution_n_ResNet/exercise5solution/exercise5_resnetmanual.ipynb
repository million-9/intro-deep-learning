# %% [markdown]
# # Exercise 5

# %%
import torch
import torch.nn as nn

# %% [markdown]
# In this exercise, we will use the CIFAR10 dataset. It consists of 32x32 color images of 10 classes (e.g. airplane, bird, frog, ..., see below). The task is to predict the correct class, given the image.

# %%
from torchvision.datasets import CIFAR10

train_data = CIFAR10('./cifar', download=True, train=True)
val_data = CIFAR10('./cifar', download=True, train=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# We can inspect the layout of the dataset:

# %%
print("len(train_data):", len(train_data))
print("len(val_data):", len(val_data))
print()
first_sample = train_data[0]
print("type(first_sample):", type(first_sample))
print("len(first_sample):", len(first_sample))
print("type(first_sample[0]):", type(first_sample[0]))
print("type(first_sample[1]):", type(first_sample[1]))
print()

image = first_sample[0]
label = first_sample[1]

print("Image size:", image.size)
print("Label:", label)
# Out:
# len(train_data): 50000
# len(val_data): 10000
#
# type(first_sample): <class 'tuple'>
# len(first_sample): 2
# type(first_sample[0]): <class 'PIL.Image.Image'>
# type(first_sample[1]): <class 'int'>
#
# Image size: (32, 32)
# Label: 6

# %% [markdown]
# According to [the website](https://www.cs.toronto.edu/~kriz/cifar.html), the classes are:

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Visualizing the data is always a good idea:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axes = plt.subplots(5, 5, figsize=(14, 14))
for i in range(25):
    image, label = train_data[i]
    ax = axes[i//5, i%5]
    ax.imshow(image)
    ax.set_title(f"Label: {classes[label]}", fontdict={"fontsize": 14})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Augmentation

# %% [markdown]
# On the training dataset, we will use some data augmentation: RandomHorizontalFlip, RandomCrop and Normalize. Flipping the image horizontally should still allow the network to guess the correct class, as e.g. a frog mirrored left-to-right is still a frog. RandomCrop will in this case yield 32x32 crops of the input image, and add padding on the sides (see visualization below). This augmentation preserves the main part of the image, but moves the image content around and adds some padding on the sides. This should still allow the network to guess the correct class, as we do not crop out too much of the image. One could also use other augmentation methods such as RandomRotation, but these are the augmentation methods described in the [original ResNet paper](https://arxiv.org/pdf/1512.03385.pdf).
#
# This augmentation can artificially enlarge the number of training examples we have in our dataset and help to prevent overfitting.

# %%
from torchvision.transforms import ToTensor, Compose, Normalize, RandomHorizontalFlip, RandomCrop
from torch.utils.data import DataLoader

# Image transforms
normalize_mean = [0.485, 0.456, 0.406]
normalize_std = [0.229, 0.224, 0.225]
normalize = Normalize(mean=normalize_mean, std=normalize_std)

train_transform = Compose([
    RandomHorizontalFlip(),
    RandomCrop(32, 4),
    ToTensor(),
    normalize
])
val_transform = Compose([
    ToTensor(),
    normalize
])

train_data_torch = CIFAR10('./cifar', download=True, train=True, transform=train_transform)
val_data_torch = CIFAR10('./cifar', download=True, train=False, transform=val_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Instead of writing our own `Loader` class, as we did in the previous exercises, we will now use the pytorch [DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) class for this. It takes a dataset that must be either iterable or indexable and have a length (`__len__`). The Dataloader can be iterated with `for batch in dataloader: ...`, as we did in the previous exercises. The DataLoader class has some improvements to our own `Loader` class, e.g. it can perform the image augmentation on dedicated worker processes, speeding up the training heavily if the augmentation is slow.

# %%
BATCH_SIZE = 128
train_loader = DataLoader(train_data_torch, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_data_torch, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)

# %% [markdown]
# ## Network

# %% [markdown]
# In this notebook, we will not use the ResNet18 model provided by torchvision. The ResNet18 model is adapted for larger images, such as the 224x224 images used in the ImageNet dataset. In the original [ResNet paper](https://arxiv.org/pdf/1512.03385.pdf), they used a slightly different architecture (ResNet20) to train and evaluate on the CIFAR-10 dataset with its 32x32 images. The changes include:
#  - Replacing the 64 7x7 filters at the start of the network with 16 3x3 filters
#  - Using 3 residual layers instead of 4, and reducing the number of filters learned in the layers (from [64, 128, 256, 512] to [16, 32, 64])
#  - Using 3 residual blocks per layer instead of 2

# %% [markdown]
# Below you will find an almost complete ResNet architecture implementation. Your task is to fill in the implementation of the `ResidualBlock` class. To recap, the ResidualBlock performs 2x `Conv + BatchNorm + ReLU`, where the first convolution may have stride 1 or 2, and the other has stride 1. The result of this is added to the input of the block (i.e., the block calculates the residual). If the block has to perform a stride or the number of channels at the beginning of the block (`channels_in`) is not equal to the number of channels the block should have (`K`), the skip connection has to perform a 1x1 convolution followed by a BatchNorm, so that the numbers of filters and the stride are matching when the addition is performed.
#
# To sum up, there are two variants that the ResidualBlock can behave in:
#
# 1. Without 1x1 convolution in the skip connection (if `channels_in == K` and `stride == 1`):
#
# <img src="residual_block_identity.svg" width="300" height="400" />
#
# 2. With 1x1 convolution in the skip connection:
#
# <img src="residual_block.svg" width="300" height="400" />

# %%
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, channels_in, K, stride=1):
        super(ResidualBlock, self).__init__()

        # stride is the stride to be performed in the first convolution. The other convolution always has stride 1.
        # channels_in is the number of channels in the input tensor
        # K is the number of filters that each convolution should learn in this block

        # TODO your implementation here
        self.conv1 = nn.Conv2d(channels_in, K, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(K)
        self.relu1 = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(K, K, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(K)

        if channels_in != K or stride != 1:
            self.skip_conv = nn.Conv2d(channels_in, K, kernel_size=1, stride=stride, bias=False)
            self.skip_bn = nn.BatchNorm2d(K)
        else:
            self.skip_conv = None
        pass

    def forward(self, x):
        # TODO your implementation here
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.skip_conv is not None:
            identity = self.skip_conv(identity)
            identity = self.skip_bn(identity)

        out += identity
        out = F.relu(out)

        return out
        pass


class ResidualLayer(nn.Module):
    def __init__(self, K_in, K, num_blocks, stride=1, block=ResidualBlock):
        super(ResidualLayer, self).__init__()

        modules = [block(K_in, K, stride=stride)]

        for j in range(num_blocks-1):
            modules.append(block(K, K))

        self.model = nn.Sequential(*modules)

    def forward(self, x):
        x = self.model(x)
        return x


class CIFAR10ResNet20(nn.Module):
    def __init__(self, num_classes, block=ResidualBlock):
        super(CIFAR10ResNet20, self).__init__()
        # number of blocks per layer
        self.layers = [3, 3, 3]
        # filter sizes / channels per layer
        self.filters = [16, 32, 64]
        # stride of the first block in each layer
        self.strides = [1, 2, 2]

        # The number of filters for the first conv layer
        C0 = 16
        modules = []
        conv1 = nn.Conv2d(3, C0, (3, 3), padding=1, stride=1, bias=False)

        modules += [
            conv1,
            nn.BatchNorm2d(C0),
            nn.ReLU()
        ]

        # instantiate all the layers
        for i in range(len(self.layers)):
            in_channels = C0 if i == 0 else self.filters[i-1]
            modules.append(ResidualLayer(
                in_channels, self.filters[i], self.layers[i], stride=self.strides[i], block=block))

        # adaptive max pooling reduces the remaining image to a 1x1 image with the previous
        # number of channels (self.filters[-1])
        modules.append(nn.AdaptiveAvgPool2d((1, 1)))

        # our model is a simple sequential flow of the previously defined modules
        # (skip connections were already handled in the ResidualBlocks)
        self.model = nn.Sequential(*modules)
        # Classification layer
        self.linear = nn.Linear(self.filters[-1], num_classes)
        # note that there is no softmax layer here because cross_entropy loss in pytorch
        # already includes the softmax operation.

        # weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(
                    m.weight, mode='fan_out', nonlinearity='relu')

    def forward(self, x):
        x = self.model(x)

        # flatten the tensor to a 1D array (but with batch_size still intact)
        x = x.view(x.size(0), -1)

        x = self.linear(x)
        return x

# %% [markdown]
# #### Training

# %% [markdown]
# Ok, now on to the actual training. We instantiate the network and the optimizer:

# %%
model = CIFAR10ResNet20(num_classes=10)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
LR = 0.1
optimizer = torch.optim.SGD(model.parameters(), lr=LR, weight_decay=0.0001, momentum=0.9)

# %%
train_losses = []
val_losses = []
train_accuracy = []
val_accuracy = []

# %% [markdown]
# The training loop is very similar to the last exercises. One difference is the addition of a `train_batch_epoch_limit` variable. This allows us to decrease the number of batches that we process per training epoch. If one does not have a GPU, iterating the whole 60000 images of the training set takes quite some time. If we decrease the number of batches per epoch, we can perform shorter epochs and thus log the training accuracy more frequently.

# %%
from torch.nn.functional import cross_entropy
import numpy as np
import tqdm

NUM_EPOCHS = 10
NUM_CLASSES = 10

train_batch_epoch_limit = 200
val_batch_epoch_limit = 200

for epoch in range(NUM_EPOCHS):
    # perform training followed by validation
    for mode, loader, batch_epoch_limit in [
        ("train", train_loader, train_batch_epoch_limit),
        ("val", val_loader, val_batch_epoch_limit)
    ]:
        # progressbar setup
        num_batches = min(len(loader), batch_epoch_limit)
        pbar = tqdm.tqdm(total=num_batches, desc=f"{mode} epoch {epoch}")

        if mode == "train":
            model.train() # do calculate gradients for training mode
        else:
            model.eval() # do not calculate gradients in validation mode

        # initial values of the metrics (loss, accurracy)
        runningLoss = 0.
        correct_predictions = 0
        # total number of images that were processed
        total_samples = 0

        # loop over the data
        for i_batch, batch in zip(range(num_batches), loader):
            images, labels = batch
            # move tensors to the correct device
            images = images.to(device)
            labels = labels.to(device)

            # run the model
            predictions = model.forward(images)

            # loss calculation
            loss = cross_entropy(predictions, labels)

            # calculate the metrics for the progress bar
            num_batch_samples = len(images)
            runningLoss += loss.item() * num_batch_samples
            correct_predictions += (torch.argmax(predictions, dim=-1) == labels).sum().item()
            total_samples += num_batch_samples

            pbar.update(1)
            pbar.set_postfix({
                "loss": runningLoss / total_samples,
                "accuracy": correct_predictions / total_samples
            })

            # weight update
            if mode == "train":
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        epoch_loss = runningLoss / total_samples
        epoch_accuracy = correct_predictions / total_samples
        if mode == "train":
            train_losses.append(epoch_loss)
            train_accuracy.append(epoch_accuracy)
        else:
            val_losses.append(epoch_loss)
            val_accuracy.append(epoch_accuracy)

        pbar.close()
# Out:
# train epoch 11:  16%|█▌        | 32/200 [00:11<00:59,  2.83it/s, loss=0.575, accuracy=0.802]
#
# train epoch 0:   0%|          | 1/200 [00:00<00:15, 12.68it/s, loss=2.43, accuracy=0.0938]
# train epoch 0:   1%|          | 2/200 [00:00<00:22,  8.64it/s, loss=2.43, accuracy=0.0938]
# train epoch 0:   1%|          | 2/200 [00:00<00:22,  8.64it/s, loss=2.39, accuracy=0.0977]
# train epoch 0:   2%|▏         | 3/200 [00:00<00:25,  7.60it/s, loss=2.39, accuracy=0.0977]
# train epoch 0:   2%|▏         | 3/200 [00:00<00:25,  7.60it/s, loss=2.37, accuracy=0.102]
# train epoch 0:   2%|▏         | 4/200 [00:00<00:27,  7.12it/s, loss=2.37, accuracy=0.102]
# train epoch 0:   2%|▏         | 4/200 [00:00<00:27,  7.12it/s, loss=2.35, accuracy=0.117]
# train epoch 0:   2%|▎         | 5/200 [00:00<00:28,  6.86it/s, loss=2.35, accuracy=0.117]
# train epoch 0:   2%|▎         | 5/200 [00:00<00:28,  6.86it/s, loss=2.35, accuracy=0.128]
# train epoch 0:   3%|▎         | 6/200 [00:00<00:30,  6.29it/s, loss=2.35, accuracy=0.128]
# train epoch 0:   3%|▎         | 6/200 [00:00<00:30,  6.29it/s, loss=2.33, accuracy=0.135]
# train epoch 0:   4%|▎         | 7/200 [00:01<00:32,  5.99it/s, loss=2.33, accuracy=0.135]
# train epoch 0:   4%|▎         | 7/200 [00:01<00:32,  5.99it/s, loss=2.32, accuracy=0.146]
# train epoch 0:   4%|▍         | 8/200 [00:01<00:31,  6.14it/s, loss=2.32, accuracy=0.146]
# train epoch 0:   4%|▍         | 8/200 [00:01<00:31,  6.14it/s, loss=2.32, accuracy=0.151]
# train epoch 0:   4%|▍         | 9/200 [00:01<00:31,  6.05it/s, loss=2.32, accuracy=0.151]
# train epoch 0:   4%|▍         | 9/200 [00:01<00:31,  6.05it/s, loss=2.31, accuracy=0.155]
# train epoch 0:   5%|▌         | 10/200 [00:01<00:31,  6.11it/s, loss=2.31, accuracy=0.155]
# train epoch 0:   5%|▌         | 10/200 [00:01<00:31,  6.11it/s, loss=2.3, accuracy=0.155]
# train epoch 0:   6%|▌         | 11/200 [00:01<00:31,  5.93it/s, loss=2.3, accuracy=0.155]
# train epoch 0:   6%|▌         | 11/200 [00:01<00:31,  5.93it/s, loss=2.28, accuracy=0.16]
# train epoch 0:   6%|▌         | 12/200 [00:01<00:31,  5.92it/s, loss=2.28, accuracy=0.16]
# train epoch 0:   6%|▌         | 12/200 [00:01<00:31,  5.92it/s, loss=2.29, accuracy=0.159]
# train epoch 0:   6%|▋         | 13/200 [00:02<00:32,  5.80it/s, loss=2.29, accuracy=0.159]
# train epoch 0:   6%|▋         | 13/200 [00:02<00:32,  5.80it/s, loss=2.28, accuracy=0.162]
# train epoch 0:   7%|▋         | 14/200 [00:02<00:32,  5.77it/s, loss=2.28, accuracy=0.162]
# train epoch 0:   7%|▋         | 14/200 [00:02<00:32,  5.77it/s, loss=2.27, accuracy=0.167]
# train epoch 0:   8%|▊         | 15/200 [00:02<00:32,  5.68it/s, loss=2.27, accuracy=0.167]
# train epoch 0:   8%|▊         | 15/200 [00:02<00:32,  5.68it/s, loss=2.27, accuracy=0.165]
# train epoch 0:   8%|▊         | 16/200 [00:02<00:32,  5.68it/s, loss=2.27, accuracy=0.165]
# train epoch 0:   8%|▊         | 16/200 [00:02<00:32,  5.68it/s, loss=2.28, accuracy=0.167]
# train epoch 0:   8%|▊         | 17/200 [00:02<00:31,  5.88it/s, loss=2.28, accuracy=0.167]
# train epoch 0:   8%|▊         | 17/200 [00:02<00:31,  5.88it/s, loss=2.28, accuracy=0.167]
# train epoch 0:   9%|▉         | 18/200 [00:02<00:31,  5.77it/s, loss=2.28, accuracy=0.167]
# train epoch 0:   9%|▉         | 18/200 [00:02<00:31,  5.77it/s, loss=2.28, accuracy=0.167]
# train epoch 0:  10%|▉         | 19/200 [00:03<00:30,  6.01it/s, loss=2.28, accuracy=0.167]
# train epoch 0:  10%|▉         | 19/200 [00:03<00:30,  6.01it/s, loss=2.27, accuracy=0.168]
# train epoch 0:  10%|█         | 20/200 [00:03<00:30,  5.89it/s, loss=2.27, accuracy=0.168]
# train epoch 0:  10%|█         | 20/200 [00:03<00:30,  5.89it/s, loss=2.26, accuracy=0.171]
# train epoch 0:  10%|█         | 21/200 [00:03<00:30,  5.90it/s, loss=2.26, accuracy=0.171]
# train epoch 0:  10%|█         | 21/200 [00:03<00:30,  5.90it/s, loss=2.25, accuracy=0.171]
# train epoch 0:  11%|█         | 22/200 [00:03<00:29,  5.98it/s, loss=2.25, accuracy=0.171]
# train epoch 0:  11%|█         | 22/200 [00:03<00:29,  5.98it/s, loss=2.25, accuracy=0.172]
# train epoch 0:  12%|█▏        | 23/200 [00:03<00:29,  6.03it/s, loss=2.25, accuracy=0.172]
# train epoch 0:  12%|█▏        | 23/200 [00:03<00:29,  6.03it/s, loss=2.24, accuracy=0.177]
# train epoch 0:  12%|█▏        | 24/200 [00:03<00:29,  6.05it/s, loss=2.24, accuracy=0.177]
# train epoch 0:  12%|█▏        | 24/200 [00:03<00:29,  6.05it/s, loss=2.23, accuracy=0.181]
# train epoch 0:  12%|█▎        | 25/200 [00:04<00:28,  6.11it/s, loss=2.23, accuracy=0.181]
# train epoch 0:  12%|█▎        | 25/200 [00:04<00:28,  6.11it/s, loss=2.22, accuracy=0.181]
# train epoch 0:  13%|█▎        | 26/200 [00:04<00:28,  6.15it/s, loss=2.22, accuracy=0.181]
# train epoch 0:  13%|█▎        | 26/200 [00:04<00:28,  6.15it/s, loss=2.21, accuracy=0.183]
# train epoch 0:  14%|█▎        | 27/200 [00:04<00:28,  6.14it/s, loss=2.21, accuracy=0.183]
# train epoch 0:  14%|█▎        | 27/200 [00:04<00:28,  6.14it/s, loss=2.21, accuracy=0.187]
# train epoch 0:  14%|█▍        | 28/200 [00:04<00:27,  6.24it/s, loss=2.21, accuracy=0.187]
# train epoch 0:  14%|█▍        | 28/200 [00:04<00:27,  6.24it/s, loss=2.2, accuracy=0.19]
# train epoch 0:  14%|█▍        | 29/200 [00:04<00:27,  6.16it/s, loss=2.2, accuracy=0.19]
# train epoch 0:  14%|█▍        | 29/200 [00:04<00:27,  6.16it/s, loss=2.19, accuracy=0.19]
# train epoch 0:  15%|█▌        | 30/200 [00:04<00:27,  6.20it/s, loss=2.19, accuracy=0.19]
# train epoch 0:  15%|█▌        | 30/200 [00:04<00:27,  6.20it/s, loss=2.18, accuracy=0.192]
# train epoch 0:  16%|█▌        | 31/200 [00:05<00:27,  6.10it/s, loss=2.18, accuracy=0.192]
# train epoch 0:  16%|█▌        | 31/200 [00:05<00:27,  6.10it/s, loss=2.17, accuracy=0.196]
# train epoch 0:  16%|█▌        | 32/200 [00:05<00:27,  6.03it/s, loss=2.17, accuracy=0.196]
# train epoch 0:  16%|█▌        | 32/200 [00:05<00:27,  6.03it/s, loss=2.17, accuracy=0.198]
# train epoch 0:  16%|█▋        | 33/200 [00:05<00:27,  5.97it/s, loss=2.17, accuracy=0.198]
# train epoch 0:  16%|█▋        | 33/200 [00:05<00:27,  5.97it/s, loss=2.16, accuracy=0.198]
# train epoch 0:  17%|█▋        | 34/200 [00:05<00:27,  6.10it/s, loss=2.16, accuracy=0.198]
# train epoch 0:  17%|█▋        | 34/200 [00:05<00:27,  6.10it/s, loss=2.15, accuracy=0.199]
# train epoch 0:  18%|█▊        | 35/200 [00:05<00:27,  6.08it/s, loss=2.15, accuracy=0.199]
# train epoch 0:  18%|█▊        | 35/200 [00:05<00:27,  6.08it/s, loss=2.15, accuracy=0.201]
# train epoch 0:  18%|█▊        | 36/200 [00:05<00:26,  6.10it/s, loss=2.15, accuracy=0.201]
# train epoch 0:  18%|█▊        | 36/200 [00:05<00:26,  6.10it/s, loss=2.13, accuracy=0.205]
# train epoch 0:  18%|█▊        | 37/200 [00:06<00:26,  6.09it/s, loss=2.13, accuracy=0.205]
# train epoch 0:  18%|█▊        | 37/200 [00:06<00:26,  6.09it/s, loss=2.13, accuracy=0.207]
# train epoch 0:  19%|█▉        | 38/200 [00:06<00:26,  6.20it/s, loss=2.13, accuracy=0.207]
# train epoch 0:  19%|█▉        | 38/200 [00:06<00:26,  6.20it/s, loss=2.12, accuracy=0.206]
# train epoch 0:  20%|█▉        | 39/200 [00:06<00:26,  6.18it/s, loss=2.12, accuracy=0.206]
# train epoch 0:  20%|█▉        | 39/200 [00:06<00:26,  6.18it/s, loss=2.12, accuracy=0.206]
# train epoch 0:  20%|██        | 40/200 [00:06<00:25,  6.24it/s, loss=2.12, accuracy=0.206]
# train epoch 0:  20%|██        | 40/200 [00:06<00:25,  6.24it/s, loss=2.11, accuracy=0.207]
# train epoch 0:  20%|██        | 41/200 [00:06<00:25,  6.24it/s, loss=2.11, accuracy=0.207]
# train epoch 0:  20%|██        | 41/200 [00:06<00:25,  6.24it/s, loss=2.11, accuracy=0.206]
# train epoch 0:  21%|██        | 42/200 [00:06<00:25,  6.17it/s, loss=2.11, accuracy=0.206]
# train epoch 0:  21%|██        | 42/200 [00:06<00:25,  6.17it/s, loss=2.1, accuracy=0.206]
# train epoch 0:  22%|██▏       | 43/200 [00:07<00:25,  6.20it/s, loss=2.1, accuracy=0.206]
# train epoch 0:  22%|██▏       | 43/200 [00:07<00:25,  6.20it/s, loss=2.1, accuracy=0.208]
# train epoch 0:  22%|██▏       | 44/200 [00:07<00:25,  6.04it/s, loss=2.1, accuracy=0.208]
# train epoch 0:  22%|██▏       | 44/200 [00:07<00:25,  6.04it/s, loss=2.09, accuracy=0.208]
# train epoch 0:  22%|██▎       | 45/200 [00:07<00:25,  5.97it/s, loss=2.09, accuracy=0.208]
# train epoch 0:  22%|██▎       | 45/200 [00:07<00:25,  5.97it/s, loss=2.09, accuracy=0.208]
# train epoch 0:  23%|██▎       | 46/200 [00:07<00:25,  6.04it/s, loss=2.09, accuracy=0.208]
# train epoch 0:  23%|██▎       | 46/200 [00:07<00:25,  6.04it/s, loss=2.08, accuracy=0.21]
# train epoch 0:  24%|██▎       | 47/200 [00:07<00:25,  6.08it/s, loss=2.08, accuracy=0.21]
# train epoch 0:  24%|██▎       | 47/200 [00:07<00:25,  6.08it/s, loss=2.08, accuracy=0.209]
# train epoch 0:  24%|██▍       | 48/200 [00:07<00:24,  6.13it/s, loss=2.08, accuracy=0.209]
# train epoch 0:  24%|██▍       | 48/200 [00:07<00:24,  6.13it/s, loss=2.08, accuracy=0.213]
# train epoch 0:  24%|██▍       | 49/200 [00:08<00:24,  6.06it/s, loss=2.08, accuracy=0.213]
# train epoch 0:  24%|██▍       | 49/200 [00:08<00:24,  6.06it/s, loss=2.07, accuracy=0.215]
# train epoch 0:  25%|██▌       | 50/200 [00:08<00:24,  6.19it/s, loss=2.07, accuracy=0.215]
# train epoch 0:  25%|██▌       | 50/200 [00:08<00:24,  6.19it/s, loss=2.07, accuracy=0.215]
# train epoch 0:  26%|██▌       | 51/200 [00:08<00:24,  6.13it/s, loss=2.07, accuracy=0.215]
# train epoch 0:  26%|██▌       | 51/200 [00:08<00:24,  6.13it/s, loss=2.07, accuracy=0.215]
# train epoch 0:  26%|██▌       | 52/200 [00:08<00:24,  5.94it/s, loss=2.07, accuracy=0.215]
# train epoch 0:  26%|██▌       | 52/200 [00:08<00:24,  5.94it/s, loss=2.07, accuracy=0.216]
# train epoch 0:  26%|██▋       | 53/200 [00:08<00:24,  6.03it/s, loss=2.07, accuracy=0.216]
# train epoch 0:  26%|██▋       | 53/200 [00:08<00:24,  6.03it/s, loss=2.07, accuracy=0.217]
# train epoch 0:  27%|██▋       | 54/200 [00:08<00:24,  5.99it/s, loss=2.07, accuracy=0.217]
# train epoch 0:  27%|██▋       | 54/200 [00:08<00:24,  5.99it/s, loss=2.07, accuracy=0.218]
# train epoch 0:  28%|██▊       | 55/200 [00:09<00:24,  6.01it/s, loss=2.07, accuracy=0.218]
# train epoch 0:  28%|██▊       | 55/200 [00:09<00:24,  6.01it/s, loss=2.06, accuracy=0.219]
# train epoch 0:  28%|██▊       | 56/200 [00:09<00:23,  6.02it/s, loss=2.06, accuracy=0.219]
# train epoch 0:  28%|██▊       | 56/200 [00:09<00:23,  6.02it/s, loss=2.06, accuracy=0.22]
# train epoch 0:  28%|██▊       | 57/200 [00:09<00:24,  5.90it/s, loss=2.06, accuracy=0.22]
# train epoch 0:  28%|██▊       | 57/200 [00:09<00:24,  5.90it/s, loss=2.06, accuracy=0.219]
# train epoch 0:  29%|██▉       | 58/200 [00:09<00:24,  5.87it/s, loss=2.06, accuracy=0.219]
# train epoch 0:  29%|██▉       | 58/200 [00:09<00:24,  5.87it/s, loss=2.05, accuracy=0.22]
# train epoch 0:  30%|██▉       | 59/200 [00:09<00:24,  5.87it/s, loss=2.05, accuracy=0.22]
# train epoch 0:  30%|██▉       | 59/200 [00:09<00:24,  5.87it/s, loss=2.05, accuracy=0.221]
# train epoch 0:  30%|███       | 60/200 [00:09<00:23,  5.87it/s, loss=2.05, accuracy=0.221]
# train epoch 0:  30%|███       | 60/200 [00:09<00:23,  5.87it/s, loss=2.05, accuracy=0.221]
# train epoch 0:  30%|███       | 61/200 [00:10<00:23,  5.97it/s, loss=2.05, accuracy=0.221]
# train epoch 0:  30%|███       | 61/200 [00:10<00:23,  5.97it/s, loss=2.05, accuracy=0.222]
# train epoch 0:  31%|███       | 62/200 [00:10<00:23,  5.96it/s, loss=2.05, accuracy=0.222]
# train epoch 0:  31%|███       | 62/200 [00:10<00:23,  5.96it/s, loss=2.05, accuracy=0.224]
# train epoch 0:  32%|███▏      | 63/200 [00:10<00:23,  5.91it/s, loss=2.05, accuracy=0.224]
# train epoch 0:  32%|███▏      | 63/200 [00:10<00:23,  5.91it/s, loss=2.04, accuracy=0.225]
# train epoch 0:  32%|███▏      | 64/200 [00:10<00:22,  5.98it/s, loss=2.04, accuracy=0.225]
# train epoch 0:  32%|███▏      | 64/200 [00:10<00:22,  5.98it/s, loss=2.04, accuracy=0.224]
# train epoch 0:  32%|███▎      | 65/200 [00:10<00:22,  5.97it/s, loss=2.04, accuracy=0.224]
# train epoch 0:  32%|███▎      | 65/200 [00:10<00:22,  5.97it/s, loss=2.04, accuracy=0.226]
# train epoch 0:  33%|███▎      | 66/200 [00:10<00:22,  6.00it/s, loss=2.04, accuracy=0.226]
# train epoch 0:  33%|███▎      | 66/200 [00:10<00:22,  6.00it/s, loss=2.04, accuracy=0.228]
# train epoch 0:  34%|███▎      | 67/200 [00:11<00:21,  6.05it/s, loss=2.04, accuracy=0.228]
# train epoch 0:  34%|███▎      | 67/200 [00:11<00:21,  6.05it/s, loss=2.03, accuracy=0.229]
# train epoch 0:  34%|███▍      | 68/200 [00:11<00:22,  5.89it/s, loss=2.03, accuracy=0.229]
# train epoch 0:  34%|███▍      | 68/200 [00:11<00:22,  5.89it/s, loss=2.03, accuracy=0.229]
# train epoch 0:  34%|███▍      | 69/200 [00:11<00:22,  5.89it/s, loss=2.03, accuracy=0.229]
# train epoch 0:  34%|███▍      | 69/200 [00:11<00:22,  5.89it/s, loss=2.03, accuracy=0.23]
# train epoch 0:  35%|███▌      | 70/200 [00:11<00:21,  5.94it/s, loss=2.03, accuracy=0.23]
# train epoch 0:  35%|███▌      | 70/200 [00:11<00:21,  5.94it/s, loss=2.02, accuracy=0.231]
# train epoch 0:  36%|███▌      | 71/200 [00:11<00:21,  6.08it/s, loss=2.02, accuracy=0.231]
# train epoch 0:  36%|███▌      | 71/200 [00:11<00:21,  6.08it/s, loss=2.02, accuracy=0.232]
# train epoch 0:  36%|███▌      | 72/200 [00:11<00:21,  6.00it/s, loss=2.02, accuracy=0.232]
# train epoch 0:  36%|███▌      | 72/200 [00:11<00:21,  6.00it/s, loss=2.02, accuracy=0.232]
# train epoch 0:  36%|███▋      | 73/200 [00:12<00:20,  6.05it/s, loss=2.02, accuracy=0.232]
# train epoch 0:  36%|███▋      | 73/200 [00:12<00:20,  6.05it/s, loss=2.02, accuracy=0.233]
# train epoch 0:  37%|███▋      | 74/200 [00:12<00:20,  6.04it/s, loss=2.02, accuracy=0.233]
# train epoch 0:  37%|███▋      | 74/200 [00:12<00:20,  6.04it/s, loss=2.01, accuracy=0.235]
# train epoch 0:  38%|███▊      | 75/200 [00:12<00:20,  6.05it/s, loss=2.01, accuracy=0.235]
# train epoch 0:  38%|███▊      | 75/200 [00:12<00:20,  6.05it/s, loss=2.01, accuracy=0.236]
# train epoch 0:  38%|███▊      | 76/200 [00:12<00:20,  6.06it/s, loss=2.01, accuracy=0.236]
# train epoch 0:  38%|███▊      | 76/200 [00:12<00:20,  6.06it/s, loss=2.01, accuracy=0.237]
# train epoch 0:  38%|███▊      | 77/200 [00:12<00:20,  6.10it/s, loss=2.01, accuracy=0.237]
# train epoch 0:  38%|███▊      | 77/200 [00:12<00:20,  6.10it/s, loss=2.01, accuracy=0.239]
# train epoch 0:  39%|███▉      | 78/200 [00:12<00:19,  6.15it/s, loss=2.01, accuracy=0.239]
# train epoch 0:  39%|███▉      | 78/200 [00:12<00:19,  6.15it/s, loss=2, accuracy=0.239]
# train epoch 0:  40%|███▉      | 79/200 [00:13<00:19,  6.17it/s, loss=2, accuracy=0.239]
# train epoch 0:  40%|███▉      | 79/200 [00:13<00:19,  6.17it/s, loss=2, accuracy=0.24]
# train epoch 0:  40%|████      | 80/200 [00:13<00:19,  6.23it/s, loss=2, accuracy=0.24]
# train epoch 0:  40%|████      | 80/200 [00:13<00:19,  6.23it/s, loss=2, accuracy=0.24]
# train epoch 0:  40%|████      | 81/200 [00:13<00:19,  6.21it/s, loss=2, accuracy=0.24]
# train epoch 0:  40%|████      | 81/200 [00:13<00:19,  6.21it/s, loss=1.99, accuracy=0.241]
# train epoch 0:  41%|████      | 82/200 [00:13<00:19,  6.18it/s, loss=1.99, accuracy=0.241]
# train epoch 0:  41%|████      | 82/200 [00:13<00:19,  6.18it/s, loss=1.99, accuracy=0.242]
# train epoch 0:  42%|████▏     | 83/200 [00:13<00:19,  6.12it/s, loss=1.99, accuracy=0.242]
# train epoch 0:  42%|████▏     | 83/200 [00:13<00:19,  6.12it/s, loss=1.99, accuracy=0.243]
# train epoch 0:  42%|████▏     | 84/200 [00:13<00:20,  5.74it/s, loss=1.99, accuracy=0.243]
# train epoch 0:  42%|████▏     | 84/200 [00:13<00:20,  5.74it/s, loss=1.99, accuracy=0.244]
# train epoch 0:  42%|████▎     | 85/200 [00:14<00:20,  5.57it/s, loss=1.99, accuracy=0.244]
# train epoch 0:  42%|████▎     | 85/200 [00:14<00:20,  5.57it/s, loss=1.98, accuracy=0.245]
# train epoch 0:  43%|████▎     | 86/200 [00:14<00:20,  5.60it/s, loss=1.98, accuracy=0.245]
# train epoch 0:  43%|████▎     | 86/200 [00:14<00:20,  5.60it/s, loss=1.98, accuracy=0.246]
# train epoch 0:  44%|████▎     | 87/200 [00:14<00:19,  5.76it/s, loss=1.98, accuracy=0.246]
# train epoch 0:  44%|████▎     | 87/200 [00:14<00:19,  5.76it/s, loss=1.98, accuracy=0.247]
# train epoch 0:  44%|████▍     | 88/200 [00:14<00:18,  5.90it/s, loss=1.98, accuracy=0.247]
# train epoch 0:  44%|████▍     | 88/200 [00:14<00:18,  5.90it/s, loss=1.97, accuracy=0.248]
# train epoch 0:  44%|████▍     | 89/200 [00:14<00:18,  6.00it/s, loss=1.97, accuracy=0.248]
# train epoch 0:  44%|████▍     | 89/200 [00:14<00:18,  6.00it/s, loss=1.97, accuracy=0.249]
# train epoch 0:  45%|████▌     | 90/200 [00:14<00:18,  6.03it/s, loss=1.97, accuracy=0.249]
# train epoch 0:  45%|████▌     | 90/200 [00:14<00:18,  6.03it/s, loss=1.97, accuracy=0.249]
# train epoch 0:  46%|████▌     | 91/200 [00:15<00:18,  6.03it/s, loss=1.97, accuracy=0.249]
# train epoch 0:  46%|████▌     | 91/200 [00:15<00:18,  6.03it/s, loss=1.97, accuracy=0.25]
# train epoch 0:  46%|████▌     | 92/200 [00:15<00:18,  5.96it/s, loss=1.97, accuracy=0.25]
# train epoch 0:  46%|████▌     | 92/200 [00:15<00:18,  5.96it/s, loss=1.96, accuracy=0.251]
# train epoch 0:  46%|████▋     | 93/200 [00:15<00:17,  6.02it/s, loss=1.96, accuracy=0.251]
# train epoch 0:  46%|████▋     | 93/200 [00:15<00:17,  6.02it/s, loss=1.96, accuracy=0.252]
# train epoch 0:  47%|████▋     | 94/200 [00:15<00:17,  6.03it/s, loss=1.96, accuracy=0.252]
# train epoch 0:  47%|████▋     | 94/200 [00:15<00:17,  6.03it/s, loss=1.96, accuracy=0.252]
# train epoch 0:  48%|████▊     | 95/200 [00:15<00:17,  6.01it/s, loss=1.96, accuracy=0.252]
# train epoch 0:  48%|████▊     | 95/200 [00:15<00:17,  6.01it/s, loss=1.96, accuracy=0.253]
# train epoch 0:  48%|████▊     | 96/200 [00:15<00:17,  5.99it/s, loss=1.96, accuracy=0.253]
# train epoch 0:  48%|████▊     | 96/200 [00:15<00:17,  5.99it/s, loss=1.96, accuracy=0.253]
# train epoch 0:  48%|████▊     | 97/200 [00:16<00:16,  6.09it/s, loss=1.96, accuracy=0.253]
# train epoch 0:  48%|████▊     | 97/200 [00:16<00:16,  6.09it/s, loss=1.96, accuracy=0.254]
# train epoch 0:  49%|████▉     | 98/200 [00:16<00:16,  6.06it/s, loss=1.96, accuracy=0.254]
# train epoch 0:  49%|████▉     | 98/200 [00:16<00:16,  6.06it/s, loss=1.95, accuracy=0.255]
# train epoch 0:  50%|████▉     | 99/200 [00:16<00:16,  6.21it/s, loss=1.95, accuracy=0.255]
# train epoch 0:  50%|████▉     | 99/200 [00:16<00:16,  6.21it/s, loss=1.95, accuracy=0.256]
# train epoch 0:  50%|█████     | 100/200 [00:16<00:16,  6.15it/s, loss=1.95, accuracy=0.256]
# train epoch 0:  50%|█████     | 100/200 [00:16<00:16,  6.15it/s, loss=1.95, accuracy=0.256]
# train epoch 0:  50%|█████     | 101/200 [00:16<00:15,  6.21it/s, loss=1.95, accuracy=0.256]
# train epoch 0:  50%|█████     | 101/200 [00:16<00:15,  6.21it/s, loss=1.95, accuracy=0.257]
# train epoch 0:  51%|█████     | 102/200 [00:16<00:15,  6.17it/s, loss=1.95, accuracy=0.257]
# train epoch 0:  51%|█████     | 102/200 [00:16<00:15,  6.17it/s, loss=1.94, accuracy=0.257]
# train epoch 0:  52%|█████▏    | 103/200 [00:17<00:15,  6.20it/s, loss=1.94, accuracy=0.257]
# train epoch 0:  52%|█████▏    | 103/200 [00:17<00:15,  6.20it/s, loss=1.94, accuracy=0.259]
# train epoch 0:  52%|█████▏    | 104/200 [00:17<00:15,  6.10it/s, loss=1.94, accuracy=0.259]
# train epoch 0:  52%|█████▏    | 104/200 [00:17<00:15,  6.10it/s, loss=1.94, accuracy=0.259]
# train epoch 0:  52%|█████▎    | 105/200 [00:17<00:16,  5.92it/s, loss=1.94, accuracy=0.259]
# train epoch 0:  52%|█████▎    | 105/200 [00:17<00:16,  5.92it/s, loss=1.94, accuracy=0.26]
# train epoch 0:  53%|█████▎    | 106/200 [00:17<00:15,  5.89it/s, loss=1.94, accuracy=0.26]
# train epoch 0:  53%|█████▎    | 106/200 [00:17<00:15,  5.89it/s, loss=1.94, accuracy=0.26]
# train epoch 0:  54%|█████▎    | 107/200 [00:17<00:15,  5.91it/s, loss=1.94, accuracy=0.26]
# train epoch 0:  54%|█████▎    | 107/200 [00:17<00:15,  5.91it/s, loss=1.93, accuracy=0.26]
# train epoch 0:  54%|█████▍    | 108/200 [00:17<00:15,  5.90it/s, loss=1.93, accuracy=0.26]
# train epoch 0:  54%|█████▍    | 108/200 [00:17<00:15,  5.90it/s, loss=1.93, accuracy=0.261]
# train epoch 0:  55%|█████▍    | 109/200 [00:18<00:15,  5.90it/s, loss=1.93, accuracy=0.261]
# train epoch 0:  55%|█████▍    | 109/200 [00:18<00:15,  5.90it/s, loss=1.93, accuracy=0.262]
# train epoch 0:  55%|█████▌    | 110/200 [00:18<00:15,  5.88it/s, loss=1.93, accuracy=0.262]
# train epoch 0:  55%|█████▌    | 110/200 [00:18<00:15,  5.88it/s, loss=1.93, accuracy=0.262]
# train epoch 0:  56%|█████▌    | 111/200 [00:18<00:15,  5.89it/s, loss=1.93, accuracy=0.262]
# train epoch 0:  56%|█████▌    | 111/200 [00:18<00:15,  5.89it/s, loss=1.93, accuracy=0.263]
# train epoch 0:  56%|█████▌    | 112/200 [00:18<00:14,  5.89it/s, loss=1.93, accuracy=0.263]
# train epoch 0:  56%|█████▌    | 112/200 [00:18<00:14,  5.89it/s, loss=1.93, accuracy=0.263]
# train epoch 0:  56%|█████▋    | 113/200 [00:18<00:14,  5.87it/s, loss=1.93, accuracy=0.263]
# train epoch 0:  56%|█████▋    | 113/200 [00:18<00:14,  5.87it/s, loss=1.93, accuracy=0.263]
# train epoch 0:  57%|█████▋    | 114/200 [00:18<00:14,  5.96it/s, loss=1.93, accuracy=0.263]
# train epoch 0:  57%|█████▋    | 114/200 [00:18<00:14,  5.96it/s, loss=1.92, accuracy=0.264]
# train epoch 0:  57%|█████▊    | 115/200 [00:19<00:13,  6.19it/s, loss=1.92, accuracy=0.264]
# train epoch 0:  57%|█████▊    | 115/200 [00:19<00:13,  6.19it/s, loss=1.92, accuracy=0.265]
# train epoch 0:  58%|█████▊    | 116/200 [00:19<00:13,  6.09it/s, loss=1.92, accuracy=0.265]
# train epoch 0:  58%|█████▊    | 116/200 [00:19<00:13,  6.09it/s, loss=1.92, accuracy=0.265]
# train epoch 0:  58%|█████▊    | 117/200 [00:19<00:13,  6.16it/s, loss=1.92, accuracy=0.265]
# train epoch 0:  58%|█████▊    | 117/200 [00:19<00:13,  6.16it/s, loss=1.92, accuracy=0.266]
# train epoch 0:  59%|█████▉    | 118/200 [00:19<00:13,  6.28it/s, loss=1.92, accuracy=0.266]
# train epoch 0:  59%|█████▉    | 118/200 [00:19<00:13,  6.28it/s, loss=1.91, accuracy=0.266]
# train epoch 0:  60%|█████▉    | 119/200 [00:19<00:12,  6.28it/s, loss=1.91, accuracy=0.266]
# train epoch 0:  60%|█████▉    | 119/200 [00:19<00:12,  6.28it/s, loss=1.91, accuracy=0.267]
# train epoch 0:  60%|██████    | 120/200 [00:19<00:12,  6.27it/s, loss=1.91, accuracy=0.267]
# train epoch 0:  60%|██████    | 120/200 [00:19<00:12,  6.27it/s, loss=1.91, accuracy=0.268]
# train epoch 0:  60%|██████    | 121/200 [00:19<00:12,  6.26it/s, loss=1.91, accuracy=0.268]
# train epoch 0:  60%|██████    | 121/200 [00:19<00:12,  6.26it/s, loss=1.91, accuracy=0.269]
# train epoch 0:  61%|██████    | 122/200 [00:20<00:12,  6.23it/s, loss=1.91, accuracy=0.269]
# train epoch 0:  61%|██████    | 122/200 [00:20<00:12,  6.23it/s, loss=1.91, accuracy=0.269]
# train epoch 0:  62%|██████▏   | 123/200 [00:20<00:12,  6.19it/s, loss=1.91, accuracy=0.269]
# train epoch 0:  62%|██████▏   | 123/200 [00:20<00:12,  6.19it/s, loss=1.91, accuracy=0.27]
# train epoch 0:  62%|██████▏   | 124/200 [00:20<00:12,  6.26it/s, loss=1.91, accuracy=0.27]
# train epoch 0:  62%|██████▏   | 124/200 [00:20<00:12,  6.26it/s, loss=1.9, accuracy=0.271]
# train epoch 0:  62%|██████▎   | 125/200 [00:20<00:12,  6.11it/s, loss=1.9, accuracy=0.271]
# train epoch 0:  62%|██████▎   | 125/200 [00:20<00:12,  6.11it/s, loss=1.9, accuracy=0.272]
# train epoch 0:  63%|██████▎   | 126/200 [00:20<00:12,  6.10it/s, loss=1.9, accuracy=0.272]
# train epoch 0:  63%|██████▎   | 126/200 [00:20<00:12,  6.10it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  64%|██████▎   | 127/200 [00:20<00:11,  6.19it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  64%|██████▎   | 127/200 [00:20<00:11,  6.19it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  64%|██████▍   | 128/200 [00:21<00:11,  6.27it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  64%|██████▍   | 128/200 [00:21<00:11,  6.27it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  64%|██████▍   | 129/200 [00:21<00:11,  6.17it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  64%|██████▍   | 129/200 [00:21<00:11,  6.17it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  65%|██████▌   | 130/200 [00:21<00:11,  6.06it/s, loss=1.9, accuracy=0.273]
# train epoch 0:  65%|██████▌   | 130/200 [00:21<00:11,  6.06it/s, loss=1.89, accuracy=0.273]
# train epoch 0:  66%|██████▌   | 131/200 [00:21<00:11,  6.11it/s, loss=1.89, accuracy=0.273]
# train epoch 0:  66%|██████▌   | 131/200 [00:21<00:11,  6.11it/s, loss=1.89, accuracy=0.274]
# train epoch 0:  66%|██████▌   | 132/200 [00:21<00:11,  6.04it/s, loss=1.89, accuracy=0.274]
# train epoch 0:  66%|██████▌   | 132/200 [00:21<00:11,  6.04it/s, loss=1.89, accuracy=0.275]
# train epoch 0:  66%|██████▋   | 133/200 [00:21<00:11,  6.01it/s, loss=1.89, accuracy=0.275]
# train epoch 0:  66%|██████▋   | 133/200 [00:21<00:11,  6.01it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  67%|██████▋   | 134/200 [00:22<00:10,  6.18it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  67%|██████▋   | 134/200 [00:22<00:10,  6.18it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  68%|██████▊   | 135/200 [00:22<00:10,  6.09it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  68%|██████▊   | 135/200 [00:22<00:10,  6.09it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  68%|██████▊   | 136/200 [00:22<00:10,  6.02it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  68%|██████▊   | 136/200 [00:22<00:10,  6.02it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  68%|██████▊   | 137/200 [00:22<00:10,  6.08it/s, loss=1.89, accuracy=0.276]
# train epoch 0:  68%|██████▊   | 137/200 [00:22<00:10,  6.08it/s, loss=1.89, accuracy=0.277]
# train epoch 0:  69%|██████▉   | 138/200 [00:22<00:10,  5.92it/s, loss=1.89, accuracy=0.277]
# train epoch 0:  69%|██████▉   | 138/200 [00:22<00:10,  5.92it/s, loss=1.88, accuracy=0.277]
# train epoch 0:  70%|██████▉   | 139/200 [00:22<00:10,  5.74it/s, loss=1.88, accuracy=0.277]
# train epoch 0:  70%|██████▉   | 139/200 [00:22<00:10,  5.74it/s, loss=1.88, accuracy=0.278]
# train epoch 0:  70%|███████   | 140/200 [00:23<00:10,  5.85it/s, loss=1.88, accuracy=0.278]
# train epoch 0:  70%|███████   | 140/200 [00:23<00:10,  5.85it/s, loss=1.88, accuracy=0.278]
# train epoch 0:  70%|███████   | 141/200 [00:23<00:09,  5.94it/s, loss=1.88, accuracy=0.278]
# train epoch 0:  70%|███████   | 141/200 [00:23<00:09,  5.94it/s, loss=1.88, accuracy=0.278]
# train epoch 0:  71%|███████   | 142/200 [00:23<00:09,  5.98it/s, loss=1.88, accuracy=0.278]
# train epoch 0:  71%|███████   | 142/200 [00:23<00:09,  5.98it/s, loss=1.88, accuracy=0.279]
# train epoch 0:  72%|███████▏  | 143/200 [00:23<00:09,  6.14it/s, loss=1.88, accuracy=0.279]
# train epoch 0:  72%|███████▏  | 143/200 [00:23<00:09,  6.14it/s, loss=1.88, accuracy=0.28]
# train epoch 0:  72%|███████▏  | 144/200 [00:23<00:09,  6.11it/s, loss=1.88, accuracy=0.28]
# train epoch 0:  72%|███████▏  | 144/200 [00:23<00:09,  6.11it/s, loss=1.88, accuracy=0.28]
# train epoch 0:  72%|███████▎  | 145/200 [00:23<00:08,  6.21it/s, loss=1.88, accuracy=0.28]
# train epoch 0:  72%|███████▎  | 145/200 [00:23<00:08,  6.21it/s, loss=1.88, accuracy=0.28]
# train epoch 0:  73%|███████▎  | 146/200 [00:24<00:08,  6.09it/s, loss=1.88, accuracy=0.28]
# train epoch 0:  73%|███████▎  | 146/200 [00:24<00:08,  6.09it/s, loss=1.88, accuracy=0.281]
# train epoch 0:  74%|███████▎  | 147/200 [00:24<00:08,  6.16it/s, loss=1.88, accuracy=0.281]
# train epoch 0:  74%|███████▎  | 147/200 [00:24<00:08,  6.16it/s, loss=1.88, accuracy=0.281]
# train epoch 0:  74%|███████▍  | 148/200 [00:24<00:08,  6.14it/s, loss=1.88, accuracy=0.281]
# train epoch 0:  74%|███████▍  | 148/200 [00:24<00:08,  6.14it/s, loss=1.87, accuracy=0.281]
# train epoch 0:  74%|███████▍  | 149/200 [00:24<00:08,  6.10it/s, loss=1.87, accuracy=0.281]
# train epoch 0:  74%|███████▍  | 149/200 [00:24<00:08,  6.10it/s, loss=1.87, accuracy=0.282]
# train epoch 0:  75%|███████▌  | 150/200 [00:24<00:08,  6.15it/s, loss=1.87, accuracy=0.282]
# train epoch 0:  75%|███████▌  | 150/200 [00:24<00:08,  6.15it/s, loss=1.87, accuracy=0.283]
# train epoch 0:  76%|███████▌  | 151/200 [00:24<00:08,  6.10it/s, loss=1.87, accuracy=0.283]
# train epoch 0:  76%|███████▌  | 151/200 [00:24<00:08,  6.10it/s, loss=1.87, accuracy=0.283]
# train epoch 0:  76%|███████▌  | 152/200 [00:25<00:07,  6.11it/s, loss=1.87, accuracy=0.283]
# train epoch 0:  76%|███████▌  | 152/200 [00:25<00:07,  6.11it/s, loss=1.87, accuracy=0.284]
# train epoch 0:  76%|███████▋  | 153/200 [00:25<00:07,  6.10it/s, loss=1.87, accuracy=0.284]
# train epoch 0:  76%|███████▋  | 153/200 [00:25<00:07,  6.10it/s, loss=1.87, accuracy=0.284]
# train epoch 0:  77%|███████▋  | 154/200 [00:25<00:07,  6.19it/s, loss=1.87, accuracy=0.284]
# train epoch 0:  77%|███████▋  | 154/200 [00:25<00:07,  6.19it/s, loss=1.87, accuracy=0.284]
# train epoch 0:  78%|███████▊  | 155/200 [00:25<00:07,  6.15it/s, loss=1.87, accuracy=0.284]
# train epoch 0:  78%|███████▊  | 155/200 [00:25<00:07,  6.15it/s, loss=1.86, accuracy=0.285]
# train epoch 0:  78%|███████▊  | 156/200 [00:25<00:07,  6.12it/s, loss=1.86, accuracy=0.285]
# train epoch 0:  78%|███████▊  | 156/200 [00:25<00:07,  6.12it/s, loss=1.86, accuracy=0.286]
# train epoch 0:  78%|███████▊  | 157/200 [00:25<00:06,  6.16it/s, loss=1.86, accuracy=0.286]
# train epoch 0:  78%|███████▊  | 157/200 [00:25<00:06,  6.16it/s, loss=1.86, accuracy=0.287]
# train epoch 0:  79%|███████▉  | 158/200 [00:26<00:06,  6.08it/s, loss=1.86, accuracy=0.287]
# train epoch 0:  79%|███████▉  | 158/200 [00:26<00:06,  6.08it/s, loss=1.86, accuracy=0.287]
# train epoch 0:  80%|███████▉  | 159/200 [00:26<00:06,  6.10it/s, loss=1.86, accuracy=0.287]
# train epoch 0:  80%|███████▉  | 159/200 [00:26<00:06,  6.10it/s, loss=1.86, accuracy=0.288]
# train epoch 0:  80%|████████  | 160/200 [00:26<00:06,  6.06it/s, loss=1.86, accuracy=0.288]
# train epoch 0:  80%|████████  | 160/200 [00:26<00:06,  6.06it/s, loss=1.86, accuracy=0.288]
# train epoch 0:  80%|████████  | 161/200 [00:26<00:06,  6.08it/s, loss=1.86, accuracy=0.288]
# train epoch 0:  80%|████████  | 161/200 [00:26<00:06,  6.08it/s, loss=1.86, accuracy=0.289]
# train epoch 0:  81%|████████  | 162/200 [00:26<00:06,  6.14it/s, loss=1.86, accuracy=0.289]
# train epoch 0:  81%|████████  | 162/200 [00:26<00:06,  6.14it/s, loss=1.86, accuracy=0.29]
# train epoch 0:  82%|████████▏ | 163/200 [00:26<00:06,  6.08it/s, loss=1.86, accuracy=0.29]
# train epoch 0:  82%|████████▏ | 163/200 [00:26<00:06,  6.08it/s, loss=1.85, accuracy=0.29]
# train epoch 0:  82%|████████▏ | 164/200 [00:27<00:05,  6.12it/s, loss=1.85, accuracy=0.29]
# train epoch 0:  82%|████████▏ | 164/200 [00:27<00:05,  6.12it/s, loss=1.85, accuracy=0.291]
# train epoch 0:  82%|████████▎ | 165/200 [00:27<00:05,  6.13it/s, loss=1.85, accuracy=0.291]
# train epoch 0:  82%|████████▎ | 165/200 [00:27<00:05,  6.13it/s, loss=1.85, accuracy=0.291]
# train epoch 0:  83%|████████▎ | 166/200 [00:27<00:05,  6.10it/s, loss=1.85, accuracy=0.291]
# train epoch 0:  83%|████████▎ | 166/200 [00:27<00:05,  6.10it/s, loss=1.85, accuracy=0.292]
# train epoch 0:  84%|████████▎ | 167/200 [00:27<00:05,  6.14it/s, loss=1.85, accuracy=0.292]
# train epoch 0:  84%|████████▎ | 167/200 [00:27<00:05,  6.14it/s, loss=1.85, accuracy=0.292]
# train epoch 0:  84%|████████▍ | 168/200 [00:27<00:05,  6.10it/s, loss=1.85, accuracy=0.292]
# train epoch 0:  84%|████████▍ | 168/200 [00:27<00:05,  6.10it/s, loss=1.85, accuracy=0.293]
# train epoch 0:  84%|████████▍ | 169/200 [00:27<00:05,  6.07it/s, loss=1.85, accuracy=0.293]
# train epoch 0:  84%|████████▍ | 169/200 [00:27<00:05,  6.07it/s, loss=1.84, accuracy=0.293]
# train epoch 0:  85%|████████▌ | 170/200 [00:28<00:04,  6.05it/s, loss=1.84, accuracy=0.293]
# train epoch 0:  85%|████████▌ | 170/200 [00:28<00:04,  6.05it/s, loss=1.84, accuracy=0.293]
# train epoch 0:  86%|████████▌ | 171/200 [00:28<00:04,  6.06it/s, loss=1.84, accuracy=0.293]
# train epoch 0:  86%|████████▌ | 171/200 [00:28<00:04,  6.06it/s, loss=1.84, accuracy=0.294]
# train epoch 0:  86%|████████▌ | 172/200 [00:28<00:04,  6.14it/s, loss=1.84, accuracy=0.294]
# train epoch 0:  86%|████████▌ | 172/200 [00:28<00:04,  6.14it/s, loss=1.84, accuracy=0.294]
# train epoch 0:  86%|████████▋ | 173/200 [00:28<00:04,  6.04it/s, loss=1.84, accuracy=0.294]
# train epoch 0:  86%|████████▋ | 173/200 [00:28<00:04,  6.04it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  87%|████████▋ | 174/200 [00:28<00:04,  6.02it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  87%|████████▋ | 174/200 [00:28<00:04,  6.02it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  88%|████████▊ | 175/200 [00:28<00:04,  6.09it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  88%|████████▊ | 175/200 [00:28<00:04,  6.09it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  88%|████████▊ | 176/200 [00:29<00:03,  6.04it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  88%|████████▊ | 176/200 [00:29<00:03,  6.04it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  88%|████████▊ | 177/200 [00:29<00:03,  6.10it/s, loss=1.84, accuracy=0.295]
# train epoch 0:  88%|████████▊ | 177/200 [00:29<00:03,  6.10it/s, loss=1.84, accuracy=0.297]
# train epoch 0:  89%|████████▉ | 178/200 [00:29<00:03,  6.12it/s, loss=1.84, accuracy=0.297]
# train epoch 0:  89%|████████▉ | 178/200 [00:29<00:03,  6.12it/s, loss=1.84, accuracy=0.297]
# train epoch 0:  90%|████████▉ | 179/200 [00:29<00:03,  6.12it/s, loss=1.84, accuracy=0.297]
# train epoch 0:  90%|████████▉ | 179/200 [00:29<00:03,  6.12it/s, loss=1.83, accuracy=0.298]
# train epoch 0:  90%|█████████ | 180/200 [00:29<00:03,  6.11it/s, loss=1.83, accuracy=0.298]
# train epoch 0:  90%|█████████ | 180/200 [00:29<00:03,  6.11it/s, loss=1.83, accuracy=0.298]
# train epoch 0:  90%|█████████ | 181/200 [00:29<00:03,  6.13it/s, loss=1.83, accuracy=0.298]
# train epoch 0:  90%|█████████ | 181/200 [00:29<00:03,  6.13it/s, loss=1.83, accuracy=0.299]
# train epoch 0:  91%|█████████ | 182/200 [00:30<00:02,  6.02it/s, loss=1.83, accuracy=0.299]
# train epoch 0:  91%|█████████ | 182/200 [00:30<00:02,  6.02it/s, loss=1.83, accuracy=0.3]
# train epoch 0:  92%|█████████▏| 183/200 [00:30<00:02,  6.01it/s, loss=1.83, accuracy=0.3]
# train epoch 0:  92%|█████████▏| 183/200 [00:30<00:02,  6.01it/s, loss=1.83, accuracy=0.3]
# train epoch 0:  92%|█████████▏| 184/200 [00:30<00:02,  6.10it/s, loss=1.83, accuracy=0.3]
# train epoch 0:  92%|█████████▏| 184/200 [00:30<00:02,  6.10it/s, loss=1.83, accuracy=0.3]
# train epoch 0:  92%|█████████▎| 185/200 [00:30<00:02,  6.12it/s, loss=1.83, accuracy=0.3]
# train epoch 0:  92%|█████████▎| 185/200 [00:30<00:02,  6.12it/s, loss=1.83, accuracy=0.301]
# train epoch 0:  93%|█████████▎| 186/200 [00:30<00:02,  6.10it/s, loss=1.83, accuracy=0.301]
# train epoch 0:  93%|█████████▎| 186/200 [00:30<00:02,  6.10it/s, loss=1.83, accuracy=0.301]
# train epoch 0:  94%|█████████▎| 187/200 [00:30<00:02,  6.23it/s, loss=1.83, accuracy=0.301]
# train epoch 0:  94%|█████████▎| 187/200 [00:30<00:02,  6.23it/s, loss=1.83, accuracy=0.302]
# train epoch 0:  94%|█████████▍| 188/200 [00:30<00:01,  6.12it/s, loss=1.83, accuracy=0.302]
# train epoch 0:  94%|█████████▍| 188/200 [00:30<00:01,  6.12it/s, loss=1.82, accuracy=0.302]
# train epoch 0:  94%|█████████▍| 189/200 [00:31<00:01,  6.09it/s, loss=1.82, accuracy=0.302]
# train epoch 0:  94%|█████████▍| 189/200 [00:31<00:01,  6.09it/s, loss=1.82, accuracy=0.302]
# train epoch 0:  95%|█████████▌| 190/200 [00:31<00:01,  6.17it/s, loss=1.82, accuracy=0.302]
# train epoch 0:  95%|█████████▌| 190/200 [00:31<00:01,  6.17it/s, loss=1.82, accuracy=0.303]
# train epoch 0:  96%|█████████▌| 191/200 [00:31<00:01,  6.12it/s, loss=1.82, accuracy=0.303]
# train epoch 0:  96%|█████████▌| 191/200 [00:31<00:01,  6.12it/s, loss=1.82, accuracy=0.303]
# train epoch 0:  96%|█████████▌| 192/200 [00:31<00:01,  6.15it/s, loss=1.82, accuracy=0.303]
# train epoch 0:  96%|█████████▌| 192/200 [00:31<00:01,  6.15it/s, loss=1.82, accuracy=0.304]
# train epoch 0:  96%|█████████▋| 193/200 [00:31<00:01,  6.04it/s, loss=1.82, accuracy=0.304]
# train epoch 0:  96%|█████████▋| 193/200 [00:31<00:01,  6.04it/s, loss=1.82, accuracy=0.304]
# train epoch 0:  97%|█████████▋| 194/200 [00:31<00:00,  6.11it/s, loss=1.82, accuracy=0.304]
# train epoch 0:  97%|█████████▋| 194/200 [00:31<00:00,  6.11it/s, loss=1.82, accuracy=0.305]
# train epoch 0:  98%|█████████▊| 195/200 [00:32<00:00,  6.06it/s, loss=1.82, accuracy=0.305]
# train epoch 0:  98%|█████████▊| 195/200 [00:32<00:00,  6.06it/s, loss=1.82, accuracy=0.306]
# train epoch 0:  98%|█████████▊| 196/200 [00:32<00:00,  6.12it/s, loss=1.82, accuracy=0.306]
# train epoch 0:  98%|█████████▊| 196/200 [00:32<00:00,  6.12it/s, loss=1.81, accuracy=0.306]
# train epoch 0:  98%|█████████▊| 197/200 [00:32<00:00,  6.06it/s, loss=1.81, accuracy=0.306]
# train epoch 0:  98%|█████████▊| 197/200 [00:32<00:00,  6.06it/s, loss=1.81, accuracy=0.307]
# train epoch 0:  99%|█████████▉| 198/200 [00:32<00:00,  6.10it/s, loss=1.81, accuracy=0.307]
# train epoch 0:  99%|█████████▉| 198/200 [00:32<00:00,  6.10it/s, loss=1.81, accuracy=0.307]
# train epoch 0: 100%|█████████▉| 199/200 [00:32<00:00,  6.14it/s, loss=1.81, accuracy=0.307]
# train epoch 0: 100%|█████████▉| 199/200 [00:32<00:00,  6.14it/s, loss=1.81, accuracy=0.308]
# train epoch 0: 100%|██████████| 200/200 [00:32<00:00,  6.16it/s, loss=1.81, accuracy=0.308]
# train epoch 0: 100%|██████████| 200/200 [00:33<00:00,  6.05it/s, loss=1.81, accuracy=0.308]
# val epoch 0: 100%|██████████| 79/79 [00:04<00:00, 18.37it/s, loss=1.77, accuracy=0.356]
# train epoch 1: 100%|██████████| 200/200 [00:32<00:00,  6.23it/s, loss=1.43, accuracy=0.469]
# val epoch 1: 100%|██████████| 79/79 [00:04<00:00, 18.37it/s, loss=1.68, accuracy=0.454]
# train epoch 2: 100%|██████████| 200/200 [00:32<00:00,  6.17it/s, loss=1.19, accuracy=0.569]
# val epoch 2: 100%|██████████| 79/79 [00:04<00:00, 18.33it/s, loss=1.21, accuracy=0.576]
# train epoch 3: 100%|██████████| 200/200 [00:32<00:00,  6.22it/s, loss=1.02, accuracy=0.633]
# val epoch 3: 100%|██████████| 79/79 [00:04<00:00, 18.41it/s, loss=1.07, accuracy=0.624]
# train epoch 4: 100%|██████████| 200/200 [00:32<00:00,  6.17it/s, loss=0.929, accuracy=0.668]
# val epoch 4: 100%|██████████| 79/79 [00:04<00:00, 18.62it/s, loss=1, accuracy=0.661]
# train epoch 5: 100%|██████████| 200/200 [00:32<00:00,  6.20it/s, loss=0.846, accuracy=0.699]
# val epoch 5: 100%|██████████| 79/79 [00:04<00:00, 16.95it/s, loss=1.11, accuracy=0.648]
# train epoch 6: 100%|██████████| 200/200 [00:34<00:00,  5.85it/s, loss=0.763, accuracy=0.733]
# val epoch 6: 100%|██████████| 79/79 [00:04<00:00, 17.27it/s, loss=0.858, accuracy=0.714]
# train epoch 7: 100%|██████████| 200/200 [00:34<00:00,  5.88it/s, loss=0.723, accuracy=0.749]
# val epoch 7: 100%|██████████| 79/79 [00:04<00:00, 17.29it/s, loss=0.867, accuracy=0.71]
# train epoch 8: 100%|██████████| 200/200 [00:34<00:00,  5.87it/s, loss=0.676, accuracy=0.762]
# val epoch 8: 100%|██████████| 79/79 [00:04<00:00, 17.31it/s, loss=0.879, accuracy=0.715]
# train epoch 9: 100%|██████████| 200/200 [00:34<00:00,  5.87it/s, loss=0.635, accuracy=0.78]
# val epoch 9: 100%|██████████| 79/79 [00:04<00:00, 17.36it/s, loss=0.838, accuracy=0.732]

# %% [markdown]
# You can leave this running for a few epochs, to see that it is learning something, and stop the training whenever you want. After that, you can plot the training progress with the following code:

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
label = 'resnet20'
axes[0].set_title('loss')
axes[0].plot(train_losses, '--', label=f"{label} (train)")
axes[0].plot(val_losses, label=f"{label} (val)")
axes[0].legend()
axes[1].set_title('accuracy')
axes[1].plot(train_accuracy, '--', label=f"{label} (train)")
axes[1].plot(val_accuracy, label=f"{label} (val)")
axes[1].legend()

plt.show()

# %% [markdown]
# If you were leaving this running for a large number of epochs (e.g. 200) on the full dataset (e.g. set train_batch_epoch_limit to a large value), you could expect the ResNet to get about 91.25% accuracy, according to the original paper. For this, one should also decrease the learning rate after 32k and 48k iterations, as described in the paper. In general, even if you stop training earlier you should notice an improvement in performance against the number of iterations i.e. decrease in train/val loss and increase of train/val accuracy.

# %% [markdown]
# ## Visualizing results

# %% [markdown]
# We can also visualize the predictions of the network on the validation set. Note that now we have to use the softmax operation on the model's results, if we want to obtain classification probabilities.

# %%
from torchvision.transforms.functional import to_pil_image
from math import ceil

num_test_samples = 25
images, labels = next(val_loader.__iter__())

num_cols = 5
num_rows = int(ceil(num_test_samples/num_cols))
fig, axes = plt.subplots(num_rows, num_cols, figsize=(14, 14))

model.eval()
predictions = model(images.to(device))
scores = nn.functional.softmax(predictions, dim=-1)
predicted_classes = torch.argmax(scores, dim=-1)
# actually if we only need the index of the class with the highest probability, we could omit the softmax operation and perform argmax on the logits directly.
# predicted_classes = torch.argmax(predictions, dim=-1)

for i in range(num_test_samples):
    image, label = images[i], labels[i]
    predicted_class = predicted_classes[i].cpu().item()

    # undo image normalization
    for channel in range(3):
        image[channel] *= normalize_std[channel]
        image[channel] += normalize_mean[channel]
    # transform tensor back to a PIL image
    image = to_pil_image(image)

    ax = axes[i//num_cols, i%num_cols]
    ax.imshow(image)
    ax.set_title(f"pred: {classes[predicted_class]}, gt: {classes[label]}", fontdict={"fontsize": 14, "color": ("green" if predicted_class == label else "red")})
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bonus tasks

# %% [markdown]
#  - The `ResidualBlock` module performs two 3x3 convolutions. In the ResNet paper, an alternative block, the bottleneck block is discussed. In this, the two 3x3 convolutions are replaced with a sequence of one 1x1 convolution, one 3x3 convolution and then a final 1x3 convolution. Here, the first 1x1 convolution reduces the number of channels of the input tensor so that the 3x3 convolution is computationally less expensive. The final 1x1 convolution then restores the previous dimension. Implement this in a `BottleneckBlock` class. You can pass the block module that should be used to the `CIFAR10ResNet20` via the `block` argument.
#  - In the residual blocks, one can also use "pre-activations" (see [this paper](https://arxiv.org/pdf/1603.05027.pdf)). This means, that BatchNorm and ReLU are performed before the convolutions instead of after them. This further increases the network performance. Adjust the block implementation accordingly.
#  - In this notebook, we only calculate the accuracy, which means that the class for which the network calculated the highest probability has to match the label. A common metric on datasets with a higher number of classes is Top-K-Accuracy. For this, the correct class has to occur in the K classes that the network predicted the highest probabilities for. Implement a Top-3-Accuracy metric and draw the graph for it.
